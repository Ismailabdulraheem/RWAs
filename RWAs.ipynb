# %%
import json
import requests
import pandas as pd
import os

# %%
api_key = os.getenv("rwa_xyz_api")

def fetch_top_rwa_assets(api_key, limit=1000):
    all_results = []
    page = 1
    per_page = 100
    
    while len(all_results) < limit:
        myQuery = json.dumps({
            "sort": {
                "direction": "desc",
                "field": "market_value_dollar"
            },
            "pagination": {
                "page": page,
                "perPage": per_page
            }
        })
        
        response = requests.get(
            "https://api.rwa.xyz/v4/assets",
            params={"query": myQuery},
            headers={"Authorization": f"Bearer {api_key}"}
        )
        
        data = response.json()
        results = data.get("results", [])
        
        all_results.extend(results)
        print(f"✓ ({len(all_results)} total)")
        
        if not results or len(results) < per_page:
            break
        
        page += 1
    
    return all_results[:limit]

top_assets = fetch_top_rwa_assets(api_key, limit=1000)
df = pd.json_normalize(top_assets)
df = df[df['market_value_dollar.val'] > 0].copy()
key_columns = [
    'name', 'ticker', 'underlying_asset_classes',
    'price_dollar.val_7d', 'daily_transfer_volume_dollar.val_7d',
    'market_value_dollar.val',
    'token_count', 'top_holder_concentration.val_7d',
]

existing = [col for col in key_columns if col in df.columns]
df_clean = df[existing].copy()

print(f"\nFinal dataset: {len(df_clean)} rows × {len(df_clean.columns)} columns")
print(df_clean.head(10))
print(df_clean['market_value_dollar.val'].describe())
# Out:
# ✓ (100 total)
# ✓ (200 total)
# ✓ (300 total)
# ✓ (400 total)
# ✓ (500 total)
# ✓ (600 total)
# ✓ (700 total)
# ✓ (800 total)
# ✓ (900 total)
# ✓ (1000 total)
#
# Final dataset: 245 rows × 8 columns
#                  name      ticker  \
# 0         Tether USDt        USDT
# 1                USDC        USDC
# 2  Figure HELOC Token  FIGR_HELOC
# 3                USDS        USDS
# 4         Ethena USDe        USDe
# 5      Dai Stablecoin         DAI
# 6                USD1        USD1
# 7          Paypal USD       PYUSD
# 8         Tether Gold        XAUT
# 9          Paxos Gold        PAXG
#
#                             underlying_asset_classes  price_dollar.val_7d  \
# 0  [Money Market - Fund, Money Market - RRP, Cryp...             1.000045
# 1                                                 []             0.999904
# 2                                               None             1.028698
# 3  [Structured Credit, Private Credit, Stablecoin...             0.999618
# 4  [Derivatives - Short ETH Perps, Cryptocurrenci...             0.999238
# 5                                                 []             0.999618
# 6                                                 []             0.999391
# 7  [Money Market - RRP, US Treasury Debt, Bank De...             1.000144
# 8                                                 []          5361.914619
# 9                                                 []          5436.421850
#
#    daily_transfer_volume_dollar.val_7d  market_value_dollar.val  token_count  \
# 0                         7.984254e+10             2.007814e+11           14
# 1                         2.485522e+11             8.048283e+10           26
# 2                                  NaN             1.602644e+10            1
# 3                         1.997370e+09             7.723058e+09            2
# 4                         2.143577e+08             6.015420e+09            3
# 5                         2.293510e+09             4.962719e+09            2
# 6                         1.120855e+09             4.492660e+09            6
# 7                         1.285671e+09             4.092393e+09            4
# 8                         6.974987e+08             3.666533e+09            3
# 9                         2.944006e+08             2.571577e+09            1
#
#    top_holder_concentration.val_7d
# 0                       437.996349
# 1                       748.730715
# 2                              NaN
# 3                        95.661771
# 4                       210.218491
# 5                        43.903110
# 6                       285.278138
# 7                       212.279927
# 8                        53.346774
# 9                        20.114161
# count    2.450000e+02
# mean     1.453974e+09
# std      1.383850e+10
# min      1.122771e-11
# 25%      7.026027e+06
# 50%      3.952340e+07
# 75%      8.268578e+07
# max      2.007814e+11
# Name: market_value_dollar.val, dtype: float64
